# %%
import pandas as pd

# %%
HEADERS = ['Sample','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']
df = pd.read_csv('wine.data',names=HEADERS)
df.head()
# Out:
#    Sample  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0       1    14.23        1.71  2.43               15.6        127
# 1       1    13.20        1.78  2.14               11.2        100
# 2       1    13.16        2.36  2.67               18.6        101
# 3       1    14.37        1.95  2.50               16.8        113
# 4       1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
df.plot.scatter(x='Alcohol',y='Flavanoids')
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Flavanoids'>

# %%
df.boxplot(column=['Proanthocyanins'])
# Out:
# <AxesSubplot:>

# %%
data2 = pd.read_csv("winequality-white.csv",sep=';')
data2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
for x in data2.columns:
    for y in data2.columns:
        data2.plot.scatter(x=x,y=y)
# Out:
# C:\Users\sauve\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
for col in data2.columns:
    data2.boxplot(column=list(data2.columns))

# %%
list(data2.columns)
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
_, bp = data2.boxplot(column=['chlorides'],return_type='both')

# %%
[median.get_ydata() for median in bp["medians"]]
# Out:
# [array([0.043, 0.043])]

# %%
[box.get_ydata() for box in bp["boxes"]]
# Out:
# [array([0.036, 0.036, 0.05 , 0.05 , 0.036])]

# %%
[whiskers.get_ydata() for whiskers in bp["whiskers"]]
# Out:
# [array([0.036, 0.015]), array([0.05 , 0.071])]

# %%
out = [flier.get_ydata() for flier in bp["fliers"]]

len(out[0])
208/4898
# Out:
# 0.04246631278072683

# %%
df
# Out:
#      Sample  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0         1    14.23        1.71  2.43               15.6        127
# 1         1    13.20        1.78  2.14               11.2        100
# 2         1    13.16        2.36  2.67               18.6        101
# 3         1    14.37        1.95  2.50               16.8        113
# 4         1    13.24        2.59  2.87               21.0        118
# ..      ...      ...         ...   ...                ...        ...
# 173       3    13.71        5.65  2.45               20.5         95
# 174       3    13.40        3.91  2.48               23.0        102
# 175       3    13.27        4.28  2.26               20.0        120
# 176       3    13.17        2.59  2.37               20.0        120
# 177       3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
df.corr(method='pearson')
# Out:
#                                 Sample   Alcohol  Malic acid       Ash  \
# Sample                        1.000000 -0.328222    0.437776 -0.049643
# Alcohol                      -0.328222  1.000000    0.094397  0.211545
# Malic acid                    0.437776  0.094397    1.000000  0.164045
# Ash                          -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash             0.517859 -0.310235    0.288500  0.443367
# Magnesium                    -0.209179  0.270798   -0.054575  0.286587
# Total phenols                -0.719163  0.289101   -0.335167  0.128980
# Flavanoids                   -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols          0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins              -0.499130  0.136698   -0.220746  0.009652
# Color intensity               0.265668  0.546364    0.248985  0.258887
# Hue                          -0.617369 -0.071747   -0.561296 -0.074667
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(df.corr())
plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_538da_row0_col0, #T_538da_row1_col1, #T_538da_row2_col2, #T_538da_row3_col3, #T_538da_row4_col4, #T_538da_row5_col5, #T_538da_row6_col6, #T_538da_row7_col7, #T_538da_row8_col8, #T_538da_row9_col9, #T_538da_row10_col10, #T_538da_row11_col11, #T_538da_row12_col12, #T_538da_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_538da_row0_col1, #T_538da_row0_col6, #T_538da_row0_col7, #T_538da_row0_col9, #T_538da_row0_col11, #T_538da_row0_col12, #T_538da_row0_col13, #T_538da_row7_col0, #T_538da_row7_col8, #T_538da_row8_col5, #T_538da_row11_col2, #T_538da_row11_col3, #T_538da_row11_col10, #T_538da_row13_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_538da_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_538da_row0_col3, #T_538da_row12_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_538da_row0_col4, #T_538da_row0_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# ...

# %%
import numpy as np

test = pd.DataFrame()

test['temp'] = np.array([14.2,16.4,11.9,15.2,18.5,22.1,19.4,25.1,23.4,18.1,22.6,17.2])
test['sales'] = np.array([215,325,185,332,406,522,412,614,544,421,445,408])
test
# Out:
#     temp  sales
# 0   14.2    215
# 1   16.4    325
# 2   11.9    185
# 3   15.2    332
# 4   18.5    406
# 5   22.1    522
# 6   19.4    412
# 7   25.1    614
# 8   23.4    544
# 9   18.1    421
# 10  22.6    445
# 11  17.2    408

# %%
test.corr()
# Out:
#            temp     sales
# temp   1.000000  0.957507
# sales  0.957507  1.000000

# %%
temp = np.array([14.2,16.4,11.9,15.2,18.5,22.1,19.4,25.1,23.4,18.1,22.6,17.2])
sales = np.array([215,325,185,332,406,522,412,614,544,421,445,408])

np.mean(temp)
# Out:
# 18.675

# %%
np.mean(sales)
# Out:
# 402.4166666666667

# %%
np.std(temp)
# Out:
# 3.8403830104127206

# %%
import math
math.sqrt(np.sum(xdiff*xdiff)/11)
# Out:
# 4.011149234548396

# %%
np.std(sales)
# Out:
# 120.67688147371983

# %%
math.sqrt(np.sum(ydiff*ydiff)/11)
# Out:
# 126.04289192993235

# %%
xdiff = temp - np.mean(temp)
xdiff
# Out:
# array([-4.475, -2.275, -6.775, -3.475, -0.175,  3.425,  0.725,  6.425,
#         4.725, -0.575,  3.925, -1.475])

# %%
ydiff = sales - np.mean(sales)
ydiff
# Out:
# array([-187.41666667,  -77.41666667, -217.41666667,  -70.41666667,
#           3.58333333,  119.58333333,    9.58333333,  211.58333333,
#         141.58333333,   18.58333333,   42.58333333,    5.58333333])

# %%
np.sum(xdiff * ydiff)/(11*math.sqrt(np.sum(xdiff*xdiff)/11)*math.sqrt(np.sum(ydiff*ydiff)/11))
# Out:
# 0.9575066230015953
